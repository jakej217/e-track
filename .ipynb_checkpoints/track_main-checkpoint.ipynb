# %%
import altair as alt
import pandas as pd

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

amazon = pd.read_csv('01-Jan-2013_to_17-Nov-2018.csv')
print(amazon)
amazon["Item Subtotal"] = amazon['Item Subtotal'].str.slice(1)
amazon["Item Subtotal"] = amazon['Item Subtotal'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d17ef2d3a638> in <module>
#       7 amazon = pd.read_csv('01-Jan-2013_to_17-Nov-2018.csv')
#       8 amazon["Item Subtotal"] = amazon['Item Subtotal'].str.split("$", n = 1, expand = True)
# ----> 9 amazon["Item Subtotal"] = amazon['Item Subtotal'].astype(float)
#
# c:\users\junyo\appdata\local\programs\python\python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# c:\users\junyo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
# ...

# %%
alt.Chart(amazon).mark_point().encode(
    x = 'Category',
    y = 'Item Subtotal',
)
